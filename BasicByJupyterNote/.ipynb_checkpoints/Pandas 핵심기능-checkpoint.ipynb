# %% [markdown]
# ## pandas 핵심기능
# ### 재색인(reindexing)

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %%
data1 = pd.Series([1.2, 3.4, 0, -2], index = ['c', 'b', 'a', 'd'])
data1
# Out:
# c    1.2
# b    3.4
# a    0.0
# d   -2.0
# dtype: float64

# %%
# 재색인
data2 = data1.reindex(['a', 'b', 'c', 'd', 'e'])
data2
# data1 은 그대로 유지
# Out:
# c    1.2
# b    3.4
# a    0.0
# d   -2.0
# dtype: float64

# %%
#중복 인덱스 일 경우 reindex -> error
data3 = pd.Series([1,2,3,4], index = ['a', 'a', 'b', 'b'])
data3
# Out:
# a    1
# a    2
# b    3
# b    4
# dtype: int64

# %%
data4 = data3.reindex(['a', 'b', 'c'])
data4 #error! ValueError: cannot reindex from a duplicate axis
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/f1/8sqqkq8j0dz3jtkx0lnjdy080000gn/T/ipykernel_1296/21915477.py in <module>
# ----> 1 data4 = data3.reindex(['a', 'b', 'c'])
#       2 data4
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    4578     )
#    4579     def reindex(self, index=None, **kwargs):
# -> 4580         return super().reindex(index=index, **kwargs)
#    4581
#    4582     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4816
#    4817         # perform the reindex on the axes
# -> 4818         return self._reindex_axes(
#    4819             axes, level, limit, tolerance, method, fill_value, copy
#    4820         ).__finalize__(self, method="reindex")
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4837
#    4838             axis = self._get_axis_number(a)
# -> 4839             obj = obj._reindex_with_indexers(
#    4840                 {axis: [new_index, indexer]},
#    4841                 fill_value=fill_value,
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4881
#    4882             # TODO: speed up on homogeneous DataFrame objects
# -> 4883             new_data = new_data.reindex_indexer(
#    4884                 index,
#    4885                 indexer,
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     668         # some axes don't allow reindexing with dups
#     669         if not allow_dups:
# --> 670             self.axes[axis]._validate_can_reindex(indexer)
#     671
#     672         if axis >= self.ndim:
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/indexes/base.py in _validate_can_reindex(self, indexer)
#    3783         # trying to reindex on an axis with duplicates
#    3784         if not self._index_as_unique and len(indexer):
# -> 3785             raise ValueError("cannot reindex from a duplicate axis")
#    3786
#    3787     def reindex(
#
# ValueError: cannot reindex from a duplicate axis

# %%
# 순차적인 데이터 재식인 시 값을 보간 or 채워 넣기 
data = pd.Series(['a', 'b', 'c'], index = [0, 2, 4])
data 
# method 옵션을 통해서 누락된 값을 어떤 값으로 설정할지 선택 가능.
data.reindex(range(6), method='ffill')
# Out:
# 0    a
# 1    a
# 2    b
# 3    b
# 4    c
# 5    c
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/f1/8sqqkq8j0dz3jtkx0lnjdy080000gn/T/ipykernel_1296/1869065587.py in <module>
# ----> 1 frame.loc[['a', 'b', 'c'], columns]
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1105         # ugly hack for GH #836
#    1106         if self._multi_take_opportunity(tup):
# -> 1107             return self._multi_take(tup)
#    1108
#    1109         return self._getitem_tuple_same_dim(tup)
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/indexing.py in _multi_take(self, tup)
#    1057         """
#    1058         # GH 836
# -> 1059         d = {
#    1060             axis: self._get_listlike_indexer(key, axis)
#    1061             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/indexing.py in <dictcomp>(.0)
#    1058         # GH 836
#    1059         d = {
# -> 1060             axis: self._get_listlike_indexer(key, axis)
#    1061             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1062         }
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['column5', 'column6'] not in index"

# %%
# Frame
frame = pd.DataFrame(np.arange(9).reshape((3,3)), 
                    index = ['a', 'b', 'c'],
                    columns = ['column1', 'column2', 'column3'])
frame
# Out:
#    column1  column2  column3
# a        0        1        2
# b        3        4        5
# c        6        7        8

# %%
# index 
frame2 = frame.reindex(['a', 'b', 'c', 'd'])
frame2
# frame
# Out:
#    column1  column2  column3
# a        0        1        2
# b        3        4        5
# c        6        7        8

# %%
# columns 예약어로 column 설정 가능.
columns = ['column3', 'column5', 'column6']
frame2 = frame.reindex(columns=columns)
frame2
# Out:
#    column3  column5  column6
# a        2      NaN      NaN
# b        5      NaN      NaN
# c        8      NaN      NaN

# %%
# loc 을 이용한 재색인 -> Error!
columns = ['column2', 'column3' ,'column5']
frame.loc[['a', 'b', 'c'], columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/f1/8sqqkq8j0dz3jtkx0lnjdy080000gn/T/ipykernel_1296/2029130173.py in <module>
#       1 columns = ['column2', 'column3' ,'column5']
# ----> 2 frame.loc[['a', 'b', 'c'], columns]
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1105         # ugly hack for GH #836
#    1106         if self._multi_take_opportunity(tup):
# -> 1107             return self._multi_take(tup)
#    1108
#    1109         return self._getitem_tuple_same_dim(tup)
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/indexing.py in _multi_take(self, tup)
#    1057         """
#    1058         # GH 836
# -> 1059         d = {
#    1060             axis: self._get_listlike_indexer(key, axis)
#    1061             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/indexing.py in <dictcomp>(.0)
#    1058         # GH 836
#    1059         d = {
# -> 1060             axis: self._get_listlike_indexer(key, axis)
#    1061             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1062         }
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /opt/anaconda3/envs/datascience/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['column5'] not in index"

# %% [markdown]
# ### 하나의 로우나 칼럼 삭제하기

# %%
# drop() : 선택한 값들이 삭제된 새로운 객체를 얻을 수 있다.
obj = pd.Series(np.arange(5.), index = ['a', 'b', 'c', 'd', 'e'])
new_obj= obj.drop('c')
new_obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj.drop(['d', 'c'])
# Out:
# a    0.0
# b    1.0
# e    4.0
# dtype: float64

# %%
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(9).reshape((3,3)),
                   index=['a', 'b', 'c'],
                   columns=['one', 'two', 'three']
                   )
data
# Out:
#    one  two  three
# a    0    1      2
# b    3    4      5
# c    6    7      8

# %%
#DataFrame 에서 행 삭제
data.drop('a')
# Out:
#    one  two  three
# b    3    4      5
# c    6    7      8

# %%
#DataFrame 에서 열 삭제, axis 키워드 사용 (1 or 'columns')
data.drop('one', axis=1)
# Out:
#    two  three
# a    1      2
# b    4      5
# c    7      8

# %%
data.drop(['one', 'three'], axis='columns')
# Out:
#    two
# a    1
# b    4
# c    7

# %%
# inplace 키워드를 이용해 원본 객체를 변경할 수 있다.
data.drop('c', inplace=True)
data
# Out:
#    one  two  three
# a    0    1      2
# b    3    4      5

# %% [markdown]
# ### 색인하기, 선택하기, 거르기

# %%
#Seires 에서의 색인, 선택, 거르기
obj = pd.Series(np.arange(5), index=['a','b','c','d','e'])
obj
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int32

# %%
# 요소 색인1 (index 라벨로 찾기)
obj['c']
# Out:
# 2

# %%
# 요소 색인2 (정수로 선택하기)
obj[2], obj[0]
# Out:
# (2, 0)

# %%
# 슬라이싱 -> 라벨 이름으로 슬라이싱하면 끝점을 포함함. 
obj['a':'c']
# Out:
# a    0
# b    1
# c    2
# dtype: int32

# %%
# 정수 색인 시 끝점 포함 x
obj[2:4]
# Out:
# c    2
# d    3
# dtype: int32

# %%
obj[['c','d','e']]
# Out:
# c    2
# d    3
# e    4
# dtype: int32

# %%
obj[obj < 3][obj > 1]
# Out:
# c    2
# dtype: int32

# %%
#DataFrame 에서의 색인 선택, 거르기
data = pd.DataFrame(np.arange(16).reshape((4,4)), 
                   index=['a','b','c','d'],
                   columns=['one','two','three','four']
                   )
data
# Out:
#    one  two  three  four
# a    0    1      2     3
# b    4    5      6     7
# c    8    9     10    11
# d   12   13     14    15

# %%
data['one']
# Out:
# a     0
# b     4
# c     8
# d    12
# Name: one, dtype: int32

# %%
data[['one','three']]
# Out:
#    one  three
# a    0      2
# b    4      6
# c    8     10
# d   12     14

# %%
# 슬라이싱으로 로우 선택
data[:2]
# Out:
#    one  two  three  four
# a    0    1      2     3
# b    4    5      6     7

# %%
data['three'] > 5
# Out:
# a    False
# b     True
# c     True
# d     True
# Name: three, dtype: bool

# %%
# 불리언 배열로 선택
data[data['three'] > 5]
# Out:
#    one  two  three  four
# b    4    5      6     7
# c    8    9     10    11
# d   12   13     14    15

# %%
#loc과 iloc 으로 선택하기
# 축의 라벨을 사용하여 DataFrame의 로우와 컬럼을 선택할 수 있음.
# loc : row, column name 순
data.loc[['a','b'],'one']
# Out:
# a    0
# b    4
# Name: one, dtype: int32

# %%
# iloc : 정수 색인 가능
# 2 is c, [2,0,3] is three, one, four
data.iloc[2,[2,0,3]]
# Out:
# three    10
# one       8
# four     11
# Name: c, dtype: int32

# %%
data.iloc[1]
# Out:
# one      4
# two      5
# three    6
# four     7
# Name: b, dtype: int32

# %%
# loc, iloc 함수는 단일 라벨이나 라벨 리스트도 지원한다.
data.loc[:'c', 'two']
# Out:
# a    1
# b    5
# c    9
# Name: two, dtype: int32

# %% [markdown]
# ### 정수 색인
